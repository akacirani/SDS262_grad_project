# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in /Users/amirm/Library/Python/3.9/lib/python/site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/amirm/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4) (2.5)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in /Users/amirm/Library/Python/3.9/lib/python/site-packages (5.2.0)
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import statistics
import numpy as np
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
list_of_event = {}
final_list = []

# %%
# Base URL for SEAS events
url_seas = "https://seas.yale.edu/news-events/events/"

# List of months to scrape
months = ['2024-04', '2024-05', '2024-06']
list_of_event_seas = {}
final_list = []

for month in months:
    url = url_seas + month
    response_seas = requests.get(url)
    html_content_seas = response_seas.content

    soup_seas = BeautifulSoup(html_content_seas, "html.parser")
    events_seas = soup_seas.find_all("div", {"class": "item-list"})
    
    events_for_month = {}
    events = soup_seas.find_all("div", {"class": "views-field-title"})
    times = soup_seas.find_all("div", {"class": "views-field-field-event-time-value"})
    
    for event, time in zip(events, times):
        event_title = event.text.strip()
        event_time = time.text.strip()
        event_link = soup_seas.find("div", {"class": "views-field-title"}).find('a')['href']
        events_for_month[event_title] = event_time
        final_list.append({'title': event_title, 'link': "seas.yale.edu" + event_link ,'date': event_time, 'department': ['seas', 'engineering', "biomedical engineering", 
              "chemical & environmental engineering", "electrical engineering", 
              "mechanical engineering", "materials science", "bme", "cee", "ee", "mems"]})


    # Store events for this month in the dictionary
    list_of_event_seas[month] = events_for_month

        

print(final_list)

print(final_list[2])
# Out:
# [{'title': 'Hugh Xiao Dissertation Defense', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Monday, April 1, 2024 - 9:00am - 11:00am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}, {'title': 'RF-Visual Perception with Applications to Mobile Sensing, Robotics, & Augmented Reality', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Monday, April 1, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}, {'title': 'The Next Leap in Hardware Systems', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 4, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}, {'title': 'EE Seminar - Towards Ultimate Efficiency in Ubiquitous ML Powered Intelligence and Green AI', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Monday, April 8, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}, {'title': 'Understanding the phase preferences of transition metal dichalcogenides - Pratibha Dev', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Wednesday, April 10, 2024 - 10:30am - 11:30am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}, {'title': 'AP Seminar: New Physics in Driven Quantum Material', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 1:00pm - 2:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}, {'title': "Yale Engineering Dean's Invited Speaker Series: Lori Goler ’91, Head of People, Meta", 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 3:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}, {'title': 'Faculty Candidate EE Seminar - Boris Landa, Yale - Th. April 11, 4pm', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}, {'title': 'YUAA Aeronautica Showcase (RSVP only)', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 7:00pm - 8:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}, {'title': 'ASML EUV Challenge', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Tuesday, April 16, 2024 - 11:00am - 2:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering' ...
# {'title': 'The Next Leap in Hardware Systems', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 4, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}

# %%
list_of_event_seas
# Out:
# {'2024-04': {'Hugh Xiao Dissertation Defense': 'Monday, April 1, 2024 - 9:00am - 11:00am',
#   'RF-Visual Perception with Applications to Mobile Sensing, Robotics, & Augmented Reality': 'Monday, April 1, 2024 - 4:00pm - 5:00pm',
#   'The Next Leap in Hardware Systems': 'Thursday, April 4, 2024 - 4:00pm - 5:00pm',
#   'EE Seminar - Towards Ultimate Efficiency in Ubiquitous ML Powered Intelligence and Green AI': 'Monday, April 8, 2024 - 4:00pm - 5:00pm',
#   'Understanding the phase preferences of transition metal dichalcogenides - Pratibha Dev': 'Wednesday, April 10, 2024 - 10:30am - 11:30am',
#   'AP Seminar: New Physics in Driven Quantum Material': 'Thursday, April 11, 2024 - 1:00pm - 2:00pm',
#   "Yale Engineering Dean's Invited Speaker Series: Lori Goler ’91, Head of People, Meta": 'Thursday, April 11, 2024 - 3:00pm - 5:00pm',
#   'Faculty Candidate EE Seminar - Boris Landa, Yale - Th. April 11, 4pm': 'Thursday, April 11, 2024 - 4:00pm - 5:00pm',
#   'YUAA Aeronautica Showcase (RSVP only)': 'Thursday, April 11, 2024 - 7:00pm - 8:00pm',
#   'ASML EUV Challenge': 'Tuesday, April 16, 2024 - 11:00am - 2:00pm',
#   'Nyquist Lecture in Electrical Engineering: Eyes, Cameras, Depth Perception and Machine Vision': 'Wednesday, April 17, 2024 - 4:00pm - 5:00pm',
#   'SEAS Faculty Meeting (Closed)': 'Thursday, April 18, 2024 - 4:00pm - 5:30pm'},
#  '2024-05': {'Yale Engineering Postdoc Q&A Series: Dean Sarah Miller': 'Wednesday, May 1, 2024 - 2:00pm - 3:00pm',
#   'Yale Engineering Unconscious Bias Talk': 'Friday, May 10, 2024 - 10:00am - 11:30am',
#   'UNIVERSITY COMMENCEMENT': 'Monday, May 20, 2024 - 10:30am - 11:30am',
#   'CS Commencement Gathering': 'Monday, May 20, 2024 - 2:30pm - 4:00pm',
#   'EE Commencement Gathering': 'Monday, May 20, 2024 - 2:30pm - 3:30pm',
#   'CEE Commencement Gathering': 'Monday, May 20, 2024 - 2:30pm - 3:30pm',
#   'MEMS Commencement Gathering': 'Monday, May 20, 2024 - 3:00pm - 4:00pm',
#   'BME Commencement Gathering': 'Monday, May 20, 2024 - 3:00pm - 4:00pm',
#   'Yale School of Engineering Commencement Celebration': 'Monday, May 20, 2024 - 3:30pm - 5:00pm'},
#  '2024-06': {}}

# %%
list_of_event_cs = {}

# URL for CS department events
url_cs = "https://cpsc.yale.edu/calendar/upcoming-events"
response_cs = requests.get(url_cs)
html_content_cs = response_cs.content

soup_cs = BeautifulSoup(html_content_cs, "html.parser")

# Find all event items
events = soup_cs.find_all("td", {"class": "views-field views-field-title"})
times = soup_cs.find_all("td", {"class": "views-field views-field-field-event-time"})


# Extract event titles and times
for event, time in zip(events, times):
    event_title = event.text.strip()
    event_time = time.text.strip()
    event_link = event.find('a')['href']
    
    final_list.append({'title': event_title, 'link': "cpsc.yale.edu" + event_link, 'date': event_time, 'department': ['cs', 'computer science']})
    list_of_event_cs[event_title] = event_time

for item in final_list:
    print(item)
# Out:
# {'title': 'Hugh Xiao Dissertation Defense', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Monday, April 1, 2024 - 9:00am - 11:00am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'RF-Visual Perception with Applications to Mobile Sensing, Robotics, & Augmented Reality', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Monday, April 1, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'The Next Leap in Hardware Systems', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 4, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'EE Seminar - Towards Ultimate Efficiency in Ubiquitous ML Powered Intelligence and Green AI', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Monday, April 8, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Understanding the phase preferences of transition metal dichalcogenides - Pratibha Dev', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Wednesday, April 10, 2024 - 10:30am - 11:30am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'AP Seminar: New Physics in Driven Quantum Material', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 1:00pm - 2:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': "Yale Engineering Dean's Invited Speaker Series: Lori Goler ’91, Head of People, Meta", 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 3:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Faculty Candidate EE Seminar - Boris Landa, Yale - Th. April 11, 4pm', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'YUAA Aeronautica Showcase (RSVP only)', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 7:00pm - 8:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'ASML EUV Challenge', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Tuesday, April 16, 2024 - 11:00am - 2:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Nyquist Lecture in Electrical Engineering: Eyes, Cameras, Depth Perception and Machine Vision', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Wednesday, April 17, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'SEAS Faculty Meeting (Closed)', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 18, 2024 - 4:00pm - 5:30pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Yale Engineering Postdoc Q&A Series: Dean Sarah Miller', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Wednesday, May 1, 2024 - 2:00pm - 3:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Yale Engineering Unconscious Bias Talk', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Friday, May 10, 2024 - 10:00am - 11:30am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'UNIVERSITY COMMENCEMENT', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 10:30am - 11:30am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'CS Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 2:30pm - 4:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'EE Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 2:30pm - 3:30pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'CEE Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 2:30pm - 3:30pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'MEMS Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 3:00pm - 4:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'BME Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 3:00pm - 4:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Yale School of Engineering Commencement Celebration', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 3:30pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'CS Talk - Sarah Cen', 'link': 'cpsc.yale.edu/event/cs-talk-sarah-cen', 'date': 'Friday, April 12, 2024 - 10:30am', 'department': ['cs', 'computer science']}
# {'title': 'CS Talk - Yiding Feng, Postdoctoral Principal Researcher/University of Chicago Booth School of Business', 'link': 'cpsc.yale.edu/event/cs-talk-yiding-feng-postdoctoral-principal-researcheruniversity-chicago-booth-school-business', 'date': 'Wednesday, April 17, 2024 - 10:30am', 'department': ['cs', 'computer science']}

# %%
list_of_event_wc = {}

# URL for wc department events
url_wc = "https://westcampus.yale.edu/calendar/upcoming-events"
response_wc = requests.get(url_wc)
html_content_wc = response_wc.content

soup_wc = BeautifulSoup(html_content_wc, "html.parser")

# Find all event items
events = soup_wc.find_all("td", {"class": "views-field views-field-title"})
times = soup_wc.find_all("h3")


# Extract event titles and times
for event, time in zip(events, times):
    event_title = event.text.strip()
    event_time = time.text.strip()
    event_link = event.find('a')['href']
    final_list.append({'title': event_title, 'link': "westcampus.yale.edu" + event_link, 'date': event_time, 'department': ['wc', 'west campus']})
    list_of_event_wc[event_title] = event_time

for item in final_list:
    print(item)
# Out:
# {'title': 'Hugh Xiao Dissertation Defense', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Monday, April 1, 2024 - 9:00am - 11:00am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'RF-Visual Perception with Applications to Mobile Sensing, Robotics, & Augmented Reality', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Monday, April 1, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'The Next Leap in Hardware Systems', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 4, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'EE Seminar - Towards Ultimate Efficiency in Ubiquitous ML Powered Intelligence and Green AI', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Monday, April 8, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Understanding the phase preferences of transition metal dichalcogenides - Pratibha Dev', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Wednesday, April 10, 2024 - 10:30am - 11:30am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'AP Seminar: New Physics in Driven Quantum Material', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 1:00pm - 2:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': "Yale Engineering Dean's Invited Speaker Series: Lori Goler ’91, Head of People, Meta", 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 3:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Faculty Candidate EE Seminar - Boris Landa, Yale - Th. April 11, 4pm', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'YUAA Aeronautica Showcase (RSVP only)', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 11, 2024 - 7:00pm - 8:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'ASML EUV Challenge', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Tuesday, April 16, 2024 - 11:00am - 2:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Nyquist Lecture in Electrical Engineering: Eyes, Cameras, Depth Perception and Machine Vision', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Wednesday, April 17, 2024 - 4:00pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'SEAS Faculty Meeting (Closed)', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': 'Thursday, April 18, 2024 - 4:00pm - 5:30pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Yale Engineering Postdoc Q&A Series: Dean Sarah Miller', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Wednesday, May 1, 2024 - 2:00pm - 3:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Yale Engineering Unconscious Bias Talk', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Friday, May 10, 2024 - 10:00am - 11:30am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'UNIVERSITY COMMENCEMENT', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 10:30am - 11:30am', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'CS Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 2:30pm - 4:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'EE Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 2:30pm - 3:30pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'CEE Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 2:30pm - 3:30pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'MEMS Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 3:00pm - 4:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'BME Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 3:00pm - 4:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Yale School of Engineering Commencement Celebration', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': 'Monday, May 20, 2024 - 3:30pm - 5:00pm', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'CS Talk - Sarah Cen', 'link': 'cpsc.yale.edu/event/cs-talk-sarah-cen', 'date': 'Friday, April 12, 2024 - 10:30am', 'department': ['cs', 'computer science']}
# {'title': 'CS Talk - Yiding Feng, Postdoctoral Principal Researcher/University of Chicago Booth School of Business', 'link': 'cpsc.yale.edu/event/cs-talk-yiding-feng-postdoctoral-principal-researcheruniversity-chicago-booth-school-business', 'date': 'Wednesday, April 17, 2024 - 10:30am', 'department': ['cs', 'computer science']}
# {'title': 'YCBI Faculty Candidate Seminar Zhichao Xu', 'link': 'westcampus.yale.edu/event/ycbi-faculty-candidate-seminar-zhichao-xu', 'date': 'April 9, 2024', 'department': ['wc', 'west campus']}
# {'title': 'Microbial Sciences Institute SMALTalk (WC ABC-373)', 'link': 'westcampus.yale.edu/event/microbial-sciences-institute-smaltalk-wc-abc-373-5', 'date': 'April 12, 2024', 'department': ['wc', 'west campus']}
# {'title': 'Happy Hour', 'link': 'westcampus.yale.edu/event/happy-hour-0', 'date': 'April 19, 2024', 'department': ['wc', 'west campus']}
# {'title': 'Microbial Sciences Institute SMALTalk (WC ABC-373)', 'link': 'westcampus.yale.edu/event/microbial-sciences-institute-smaltalk-wc-abc-373-3', 'date': 'April 24, 2024', 'department': ['wc', 'west campus']}
# {'title': 'Yale Systems Biology Institute 2024 Seminar Series presentation', 'link': 'westcampus.yale.edu/event/yale-systems-biology-institute-2024-seminar-series-presentation', 'date': 'April 26, 2024', 'department': ['wc', 'west campus']}
# {'title': 'Microbial Sciences Institute SMALTalk (WC ABC-373)', 'link': 'westcampus.yale.edu/event/microbial-sciences-institute-smaltalk-wc-abc-373-4', 'date': 'May 3, 2024', 'department': ['wc', 'west campus']}
# {'title': 'Yale Cancer Biology Institute Seminar Series presents: Bing Zhang', 'link': 'westcampus.yale.edu/event/yale-cancer-biology-institute-seminar-series-presents-bing-zhang', 'date': 'May 10, 2024', 'department': ['wc', 'west campus']}

# %%
list_of_event_ap = {}

# URL for AP department events
url_ap = "https://appliedphysics.yale.edu/calendar"
response_ap = requests.get(url_ap)
html_content_ap = response_ap.content

soup_ap = BeautifulSoup(html_content_ap, "html.parser")

# Find all event items
events_ap = soup_ap.find_all("td", {"class": "views-field views-field-title"})
times_ap = soup_ap.find_all("td", {"class": "views-field views-field-field-event-time-1"})

# Extract event titles and times
for event, time in zip(events_ap, times_ap):
    event_title = event.text.strip()
    event_time = time.text.strip()
    event_link = event.find('a')['href']
    list_of_event_ap[event_title] = event_time
    final_list.append({'title': event_title, 'link': "appliedphysics.yale.edu" + event_link, 'date': event_time, 'department': ['ap', 'applied physics']})

# %%
final_list
# Out:
# [{'title': 'Hugh Xiao Dissertation Defense',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Monday, April 1, 2024 - 9:00am - 11:00am',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'RF-Visual Perception with Applications to Mobile Sensing, Robotics, & Augmented Reality',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Monday, April 1, 2024 - 4:00pm - 5:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'The Next Leap in Hardware Systems',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Thursday, April 4, 2024 - 4:00pm - 5:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'EE Seminar - Towards Ultimate Efficiency in Ubiquitous ML Powered Intelligence and Green AI',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Monday, April 8, 2024 - 4:00pm - 5:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'Understanding the phase preferences of transition metal dichalcogenides - Pratibha Dev',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Wednesday, April 10, 2024 - 10:30am - 11:30am',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'AP Seminar: New Physics in Driven Quantum Material',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Thursday, April 11, 2024 - 1:00pm - 2:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': "Yale Engineering Dean's Invited Speaker Series: Lori Goler ’91, Head of People, Meta",
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Thursday, April 11, 2024 - 3:00pm - 5:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'Faculty Candidate EE Seminar - Boris Landa, Yale - Th. April 11, 4pm',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Thursday, April 11, 2024 - 4:00pm - 5:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'YUAA Aeronautica Showcase (RSVP only)',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Thursday, April 11, 2024 - 7:00pm - 8:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'ASML EUV Challenge',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Tuesday, April 16, 2024 - 11:00am - 2:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'Nyquist Lecture in Electrical Engineering: Eyes, Cameras, Depth Perception and Machine Vision',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Wednesday, April 17, 2024 - 4:00pm - 5:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'SEAS Faculty Meeting (Closed)',
#   'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense',
#   'date': 'Thursday, April 18, 2024 - 4:00pm - 5:30pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'Yale Engineering Postdoc Q&A Series: Dean Sarah Miller',
#   'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller',
#   'date': 'Wednesday, May 1, 2024 - 2:00pm - 3:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'Yale Engineering Unconscious Bias Talk',
#   'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller',
#   'date': 'Friday, May 10, 2024 - 10:00am - 11:30am',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'UNIVERSITY COMMENCEMENT',
#   'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller',
#   'date': 'Monday, May 20, 2024 - 10:30am - 11:30am',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'CS Commencement Gathering',
#   'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller',
#   'date': 'Monday, May 20, 2024 - 2:30pm - 4:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'EE Commencement Gathering',
#   'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller',
#   'date': 'Monday, May 20, 2024 - 2:30pm - 3:30pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'CEE Commencement Gathering',
#   'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller',
#   'date': 'Monday, May 20, 2024 - 2:30pm - 3:30pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'MEMS Commencement Gathering',
#   'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller',
#   'date': 'Monday, May 20, 2024 - 3:00pm - 4:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'BME Commencement Gathering',
#   'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller',
#   'date': 'Monday, May 20, 2024 - 3:00pm - 4:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'Yale School of Engineering Commencement Celebration',
#   'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller',
#   'date': 'Monday, May 20, 2024 - 3:30pm - 5:00pm',
#   'department': ['seas',
#    'engineering',
#    'biomedical engineering',
#    'chemical & environmental engineering',
#    'electrical engineering',
#    'mechanical engineering',
#    'materials science',
#    'bme',
#    'cee',
#    'ee',
#    'mems']},
#  {'title': 'CS Talk - Sarah Cen',
#   'link': 'cpsc.yale.edu/event/cs-talk-sarah-cen',
#   'date': 'Friday, April 12, 2024 - 10:30am',
#   'department': ['cs', 'computer science']},
#  {'title': 'CS Talk - Yiding Feng, Postdoctoral Principal Researcher/University of Chicago Booth School of Business',
#   'link': 'cpsc.yale.edu/event/cs-talk-yiding-feng-postdoctoral-principal-researcheruniversity-chicago-booth-school-business',
#   'date': 'Wednesday, April 17, 2024 - 10:30am',
#   'department': ['cs', 'computer science']},
#  {'title': 'YCBI Faculty Candidate Seminar Zhichao Xu',
#   'link': 'westcampus.yale.edu/event/ycbi-faculty-candidate-seminar-zhichao-xu',
#   'date': 'April 9, 2024',
#   'department': ['wc', 'west campus']},
#  {'title': 'Microbial Sciences Institute SMALTalk (WC ABC-373)',
#   'link': 'westcampus.yale.edu/event/microbial-sciences-institute-smaltalk-wc-abc-373-5',
#   'date': 'April 12, 2024',
#   'department': ['wc', 'west campus']},
#  {'title': 'Happy Hour',
#   'link': 'westcampus.yale.edu/event/happy-hour-0',
#   'date': 'April 19, 2024',
#   'department': ['wc', 'west campus']},
#  {'title': 'Microbial Sciences Institute SMALTalk (WC ABC-373)',
#   'link': 'westcampus.yale.edu/event/microbial-sciences-institute-smaltalk-wc-abc-373-3',
#   'date': 'April 24, 2024',
#   'department': ['wc', 'west campus']},
#  {'title': 'Yale Systems Biology Institute 2024 Seminar Series presentation',
#   'link': 'westcampus.yale.edu/event/yale-systems-biology-institute-2024-seminar-series-presentation',
#   'date': 'April 26, 2024',
#   'department': ['wc', 'west campus']},
#  {'title': 'Microbial Sciences Institute SMALTalk (WC ABC-373)',
#   'link': 'westcampus.yale.edu/event/microbial-sciences-institute-smaltalk-wc-abc-373-4',
#   'date': 'May 3, 2024',
#   'department': ['wc', 'west campus']},
#  {'title': 'Yale Cancer Biology Institute Seminar Series presents: Bing Zhang',
#   'link': 'westcampus.yale.edu/event/yale-cancer-biology-institute-seminar-series-presents-bing-zhang',
#   'date': 'May 10, 2024',
#   'department': ['wc', 'west campus']},
#  {'title': 'Dissertation Defense - Lang Zhang',
#   'link': 'appliedphysics.yale.edu/event/dissertation-defense-lang-zhang',
#   'date': 'Wednesday, April 10, 2024 - 10:00am',
#   'department': ['ap', 'applied physics']},
#  {'title': 'SSO Seminar with John Davis',
#   'link': 'appliedphysics.yale.edu/event/sso-seminar-john-davis',
#   'date': 'Wednesday, April 10, 2024 - 1:00pm',
#   'department': ['ap', 'applied physics']},
#  {'title': "Dean's Special Speaker Series - Andrea Cavalleri, Max Planck Institute – “New Physics in Driven Quantum Materials”",
#   'link': 'appliedphysics.yale.edu/event/deans-special-speaker-series-andrea-cavalleri-max-planck-institute-new-physics-driven-quantum',
#   'date': 'Thursday, April 11, 2024 - 1:00pm',
#   'department': ['ap', 'applied physics']},
#  {'title': 'Applied Physics Seminar with John Sous',
#   'link': 'appliedphysics.yale.edu/event/applied-physics-seminar-john-sous',
#   'date': 'Monday, April 15, 2024 - 10:15am',
#   'department': ['ap', 'applied physics']},
#  {'title': 'Special SSO Seminar with Dr. Ori Henderson-Sapir from University of Adelaide',
#   'link': 'appliedphysics.yale.edu/event/special-sso-seminar-dr-ori-henderson-sapir-university-adelaide',
#   'date': 'Friday, April 19, 2024 - 11:00am',
#   'department': ['ap', 'applied physics']},
#  {'title': 'Applied Physics Seminar with Bumho Kim',
#   'link': 'appliedphysics.yale.edu/event/applied-physics-seminar-bumho-kim',
#   'date': 'Monday, April 22, 2024 - 10:15am',
#   'department': ['ap', 'applied physics']},
#  {'title': 'Special SSO Seminar with Ramy El-Ganainy',
#   'link': 'appliedphysics.yale.edu/event/special-sso-seminar-ramy-el-ganainy',
#   'date': 'Tuesday, April 23, 2024 - 11:00am to 12:00pm',
#   'department': ['ap', 'applied physics']},
#  {'title': 'SSO Seminar with Dr. Long Ju',
#   'link': 'appliedphysics.yale.edu/event/sso-seminar-dr-long-ju',
#   'date': 'Wednesday, April 24, 2024 - 1:00pm',
#   'department': ['ap', 'applied physics']}]

# %%
# Function to convert date string to desired format
def convert_date(date_str):
    try:
        # Split the date string based on the dash (-) character and take the first part
        date_str = date_str.split(' - ')[0]
        # Parse the date string
        date_obj = datetime.strptime(date_str, '%A, %B %d, %Y') #Monday, May 20, 2024 - 2:30pm - 4:00pm
        # Format the date object to desired format
        return date_obj.strftime('%Y-%m-%d')
    except ValueError:
        pass
    try:
        # Parse the date string
        date_obj = datetime.strptime(date_str, '%B %d, %Y') # April 19, 2024
        # Format the date object to desired format
        return date_obj.strftime('%Y-%m-%d')
    except ValueError:
        return None

# Iterate over the list and update the date format
for event in final_list:
    event['date'] = convert_date(event['date'])

# Print the updated list
for event in final_list:
    print(event)
# Out:
# {'title': 'Hugh Xiao Dissertation Defense', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-01', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'RF-Visual Perception with Applications to Mobile Sensing, Robotics, & Augmented Reality', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-01', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'The Next Leap in Hardware Systems', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-04', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'EE Seminar - Towards Ultimate Efficiency in Ubiquitous ML Powered Intelligence and Green AI', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-08', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Understanding the phase preferences of transition metal dichalcogenides - Pratibha Dev', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-10', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'AP Seminar: New Physics in Driven Quantum Material', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-11', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': "Yale Engineering Dean's Invited Speaker Series: Lori Goler ’91, Head of People, Meta", 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-11', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Faculty Candidate EE Seminar - Boris Landa, Yale - Th. April 11, 4pm', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-11', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'YUAA Aeronautica Showcase (RSVP only)', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-11', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'ASML EUV Challenge', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-16', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Nyquist Lecture in Electrical Engineering: Eyes, Cameras, Depth Perception and Machine Vision', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-17', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'SEAS Faculty Meeting (Closed)', 'link': 'seas.yale.edu/news-events/events/hugh-xiao-dissertation-defense', 'date': '2024-04-18', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Yale Engineering Postdoc Q&A Series: Dean Sarah Miller', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': '2024-05-01', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Yale Engineering Unconscious Bias Talk', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': '2024-05-10', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'UNIVERSITY COMMENCEMENT', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': '2024-05-20', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'CS Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': '2024-05-20', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'EE Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': '2024-05-20', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'CEE Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': '2024-05-20', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'MEMS Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': '2024-05-20', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'BME Commencement Gathering', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': '2024-05-20', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'Yale School of Engineering Commencement Celebration', 'link': 'seas.yale.edu/news-events/events/yale-engineering-postdoc-qa-series-dean-sarah-miller', 'date': '2024-05-20', 'department': ['seas', 'engineering', 'biomedical engineering', 'chemical & environmental engineering', 'electrical engineering', 'mechanical engineering', 'materials science', 'bme', 'cee', 'ee', 'mems']}
# {'title': 'CS Talk - Sarah Cen', 'link': 'cpsc.yale.edu/event/cs-talk-sarah-cen', 'date': '2024-04-12', 'department': ['cs', 'computer science']}
# {'title': 'CS Talk - Yiding Feng, Postdoctoral Principal Researcher/University of Chicago Booth School of Business', 'link': 'cpsc.yale.edu/event/cs-talk-yiding-feng-postdoctoral-principal-researcheruniversity-chicago-booth-school-business', 'date': '2024-04-17', 'department': ['cs', 'computer science']}
# {'title': 'YCBI Faculty Candidate Seminar Zhichao Xu', 'link': 'westcampus.yale.edu/event/ycbi-faculty-candidate-seminar-zhichao-xu', 'date': '2024-04-09', 'department': ['wc', 'west campus']}
# {'title': 'Microbial Sciences Institute SMALTalk (WC ABC-373)', 'link': 'westcampus.yale.edu/event/microbial-sciences-institute-smaltalk-wc-abc-373-5', 'date': '2024-04-12', 'department': ['wc', 'west campus']}
# {'title': 'Happy Hour', 'link': 'westcampus.yale.edu/event/happy-hour-0', 'date': '2024-04-19', 'department': ['wc', 'west campus']}
# {'title': 'Microbial Sciences Institute SMALTalk (WC ABC-373)', 'link': 'westcampus.yale.edu/event/microbial-sciences-institute-smaltalk-wc-abc-373-3', 'date': '2024-04-24', 'department': ['wc', 'west campus']}
# {'title': 'Yale Systems Biology Institute 2024 Seminar Series presentation', 'link': 'westcampus.yale.edu/event/yale-systems-biology-institute-2024-seminar-series-presentation', 'date': '2024-04-26', 'department': ['wc', 'west campus']}
# {'title': 'Microbial Sciences Institute SMALTalk (WC ABC-373)', 'link': 'westcampus.yale.edu/event/microbial-sciences-institute-smaltalk-wc-abc-373-4', 'date': '2024-05-03', 'department': ['wc', 'west campus']}
# {'title': 'Yale Cancer Biology Institute Seminar Series presents: Bing Zhang', 'link': 'westcampus.yale.edu/event/yale-cancer-biology-institute-seminar-series-presents-bing-zhang', 'date': '2024-05-10', 'department': ['wc', 'west campus']}
# {'title': 'Dissertation Defense - Lang Zhang', 'link': 'appliedphysics.yale.edu/event/dissertation-defense-lang-zhang', 'date': '2024-04-10', 'department': ['ap', 'applied physics']}
# {'title': 'SSO Seminar with John Davis', 'link': 'appliedphysics.yale.edu/event/sso-seminar-john-davis', 'date': '2024-04-10', 'department': ['ap', 'applied physics']}
# {'title': "Dean's Special Speaker Series - Andrea Cavalleri, Max Planck Institute – “New Physics in Driven Quantum Materials”", 'link': 'appliedphysics.yale.edu/event/deans-special-speaker-series-andrea-cavalleri-max-planck-institute-new-physics-driven-quantum', 'date': '2024-04-11', 'department': ['ap', 'applied physics']}
# {'title': 'Applied Physics Seminar with John Sous', 'link': 'appliedphysics.yale.edu/event/applied-physics-seminar-john-sous', 'date': '2024-04-15', 'department': ['ap', 'applied physics']}
# {'title': 'Special SSO Seminar with Dr. Ori Henderson-Sapir from University of Adelaide', 'link': 'appliedphysics.yale.edu/event/special-sso-seminar-dr-ori-henderson-sapir-university-adelaide', 'date': '2024-04-19', 'department': ['ap', 'applied physics']}
# {'title': 'Applied Physics Seminar with Bumho Kim', 'link': 'appliedphysics.yale.edu/event/applied-physics-seminar-bumho-kim', 'date': '2024-04-22', 'department': ['ap', 'applied physics']}
# {'title': 'Special SSO Seminar with Ramy El-Ganainy', 'link': 'appliedphysics.yale.edu/event/special-sso-seminar-ramy-el-ganainy', 'date': '2024-04-23', 'department': ['ap', 'applied physics']}
# {'title': 'SSO Seminar with Dr. Long Ju', 'link': 'appliedphysics.yale.edu/event/sso-seminar-dr-long-ju', 'date': '2024-04-24', 'department': ['ap', 'applied physics']}
